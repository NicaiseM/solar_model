# %% [markdown]
# <a href="https://colab.research.google.com/github/NicaiseM/solar_model/blob/master/solar_energy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Энергосберегающие технологии и альтернативные источники энергии
#
# ## Расчет потребляемой мощности и эффективности солнечных батарей
#
# ### Загрузка программы обработки и исходных данных

# %%
# !pip install git+https://github.com/building-energy/epw.git@master
from google.colab import files

# !git clone https://github.com/NicaiseM/solar_model
# %cd ./solar_model

electrical_power_file = r'./raw_data/my_home_electricity.csv'
heat_power_file = r'./raw_data/my_home_heat.csv'
weather_file = r'./raw_data/RUS_Arkhangelsk.225500_IWEC.epw'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/building-energy/epw.git (to revision master) to /tmp/pip-req-build-xz1f_rhx
#   Running command git clone -q https://github.com/building-energy/epw.git /tmp/pip-req-build-xz1f_rhx
# ...
#   Created wheel for epw: filename=epw-0.0.0-py3-none-any.whl size=3353 sha256=6cb744152fb6bb31b10eedc7ec7841a7fd2f0b281cf10cca966a633a4e91f2a8
#   Stored in directory: /tmp/pip-ephem-wheel-cache-91e8cjvp/wheels/4a/6d/bc/1eb5dd9aec49484d76a3ecbb67cd91acb9161848f4720098ba
# Successfully built epw
# ...
# Cloning into 'solar_model'...
# remote: Enumerating objects: 37, done.
# remote: Counting objects: 100% (37/37), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 37 (delta 9), reused 34 (delta 6), pack-reused 0
# Unpacking objects: 100% (37/37), done.
# /content/solar_model

# %% [markdown]
# ### Построение графика потребления электроэнергии

# %%
import main
model = main.model.Model()
model.processing(electrical_power_file, 'electrical_power')
model.processing(heat_power_file, 'heat_power')

# %% [markdown]
# ### Вывод таблиц энергопотребления

# %%
print('Потребление электрической энергии\n' + 25*'-')
print('Исходная таблица')
display(model.power[0][0])
print('Таблица по категориям')
display(model.power[0][1])
print('Таблица по категориям по месяцам')
display(model.power[0][2])
print(25*'=')
print('Потребление тепловой энергии\n' + 25*'-')
print('Исходная таблица')
display(model.power[1][0])
print('Таблица по категориям')
display(model.power[1][1])
print('Таблица по категориям по месяцам')
display(model.power[1][2])
# Out:
# Потребление электрической энергии
# -------------------------
# Исходная таблица
#                  Datetime 1 LVL TZ: Zone Lights Electricity Rate (W) - Hourly  \
# 0     1900-01-01 00:00:00                                               75.0
# 1     1900-01-01 01:00:00                                                0.0
# 2     1900-01-01 02:00:00                                                0.0
# 3     1900-01-01 03:00:00                                                0.0
# 4     1900-01-01 04:00:00                                                0.0
# ...                   ...                                                ...
# 8923  1900-12-31 20:00:00                                           41.52616
# 8924  1900-12-31 21:00:00                                                0.0
# 8925  1900-12-31 22:00:00                                                0.0
# 8926  1900-12-31 23:00:00                                              900.0
# ...
